# %%
import pandas as pd

# 1. Recharge le fichier brut d'origine (avant tes modifications) pour voir sa taille initiale
df_brut = pd.read_csv(
    "../data/processed/dataset_irve_clean.csv",
    low_memory=False,
    on_bad_lines="skip",
)
print(df_brut.shape)
print(df_brut.isna().sum())
# Out:
# (164142, 19)
# id_station_itinerance       0
# id_pdc_itinerance           0
# nom_amenageur               0
# nom_operateur               0
# nom_station                 0
# implantation_station        0
# condition_acces             0
# consolidated_latitude       0
# consolidated_longitude      0
# code_insee_commune          0
# consolidated_code_postal    0
# consolidated_commune        0
# code_departement            0
# puissance_nominale          0
# prise_type_2                0
# prise_type_combo_ccs        0
# prise_type_ef               0
# prise_type_chademo          0
# nbre_pdc_reel               0
# dtype: int64

# %%
# 1. Recharge le fichier brut d'origine (avant tes modifications) pour voir sa taille initiale
df = pd.read_csv(
    "../data/processed/dataset_irve_pop_clean.csv",
    low_memory=False,
    on_bad_lines="skip",
)
print(df.shape)
df.isna().sum()
# Out:
# (159252, 22)
# id_station_itinerance       0
# id_pdc_itinerance           0
# nom_amenageur               0
# nom_operateur               0
# nom_station                 0
# implantation_station        0
# condition_acces             0
# code_insee_commune          0
# consolidated_code_postal    0
# consolidated_commune        0
# code_departement            0
# puissance_nominale          0
# prise_type_2                0
# prise_type_combo_ccs        0
# prise_type_ef               0
# prise_type_chademo          0
# nbre_pdc_reel               0
# code_commune                0
# nom_commune                 0
# population                  0
# departement                 0
# region                      0
# dtype: int64
